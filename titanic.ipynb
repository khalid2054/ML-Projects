# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score,accuracy_score,classification_report

# %% [markdown]
# ## DATA PROCESSINGGGG>>>>>

# %%
df = pd.read_csv('titanic_eda')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  alone
# 0         0       3    male  22.0      1      0   7.2500        S  False
# 1         1       1  female  38.0      1      0  71.2833        C  False
# 2         1       3  female  26.0      0      0   7.9250        S   True
# 3         1       1  female  35.0      1      0  53.1000        S  False
# 4         0       3    male  35.0      0      0   8.0500        S   True
# 5         0       3    male  28.0      0      0   8.4583        Q   True
# 6         0       1    male  54.0      0      0  51.8625        S   True
# 7         0       3    male   2.0      3      1  21.0750        S  False
# 8         1       3  female  27.0      0      2  11.1333        S  False
# 9         1       2  female  14.0      1      0  30.0708        C  False

# %%
df.dropna(subset=['embarked'],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  889 non-null    int64
#  1   pclass    889 non-null    int64
#  2   sex       889 non-null    object
#  3   age       889 non-null    float64
#  4   sibsp     889 non-null    int64
#  5   parch     889 non-null    int64
#  6   fare      889 non-null    float64
#  7   embarked  889 non-null    object
#  8   alone     889 non-null    bool
# dtypes: bool(1), float64(2), int64(4), object(2)
# memory usage: 56.6+ KB

# %%
df['sex']= df['sex'].map({'male' : 1 , 'female' : 0})
df['alone'] = df['alone'].map({True : 1 , False : 0}) 
df = pd.get_dummies(df , columns=['embarked'], drop_first= True)

# %%
df_cleaned = df.copy()
final_df = df_cleaned.astype(int)
print(final_df.head())
# Out:
#    survived  pclass  sex  age  sibsp  parch  fare  alone  embarked_Q  \
# 0         0       3    1   22      1      0     7      0           0
# 1         1       1    0   38      1      0    71      0           0
# 2         1       3    0   26      0      0     7      1           0
# 3         1       1    0   35      1      0    53      0           0
# 4         0       3    1   35      0      0     8      1           0
#
#    embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
X = df_cleaned.drop('survived',axis=1)
y = df_cleaned['survived']

# %%
X_train_unscaled, X_test_unscaled, y_train_unscaled, y_test_unscaled = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train_scaled, X_test_scaled, y_train_scaled, y_test_scaled = train_test_split(X, y, test_size=0.20, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_scaled)
X_test_scaled = scaler.transform(X_test_scaled)

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
linear_model = LogisticRegression()
linear_model.fit(X_train_scaled, y_train_scaled)
y_predict = linear_model.predict(X_test_scaled)

# %%
f1_score(y_test_scaled,y_predict,average="weighted")
# Out:
# 0.8040907549383163

# %%
accuracy_score(y_test_scaled,y_predict)
# Out:
# 0.8033707865168539

# %%
print(classification_report(y_test_scaled,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       109
#            1       0.74      0.77      0.75        69
#
#     accuracy                           0.80       178
#    macro avg       0.79      0.80      0.79       178
# weighted avg       0.81      0.80      0.80       178

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=10)
knn_model.fit(X_train_scaled,y_train_scaled)
knn_y_predict = knn_model.predict(X_test_scaled)

# %%
f1_score(y_test_scaled,knn_y_predict,average="weighted")
# Out:
# 0.8138051417628417

# %%
accuracy_score(y_test_scaled,knn_y_predict)
# Out:
# 0.8146067415730337

# %%
print(classification_report(y_test_scaled,knn_y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       109
#            1       0.77      0.74      0.76        69
#
#     accuracy                           0.81       178
#    macro avg       0.81      0.80      0.80       178
# weighted avg       0.81      0.81      0.81       178

# %% [markdown]
# ## NIAVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model.fit(X_train_unscaled,y_train_unscaled)
predict_nb = nb_model.predict(X_test_unscaled)

# %%
f1_score(y_test_unscaled,predict_nb,average="weighted")
# Out:
# 0.7987112003111814

# %%
accuracy_score(y_test_unscaled,predict_nb)
# Out:
# 0.797752808988764

# %%
print(classification_report(y_test_unscaled,predict_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       109
#            1       0.73      0.77      0.75        69
#
#     accuracy                           0.80       178
#    macro avg       0.79      0.79      0.79       178
# weighted avg       0.80      0.80      0.80       178

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(random_state=42)
model_dt.fit(X_train_unscaled,y_train_unscaled)
dt_y_predict = model_dt.predict(X_test_unscaled)

# %%
print(f'DT model f-1 score : {f1_score(y_test_unscaled,dt_y_predict,average="weighted")}')
# Out:
# DT model f-1 score : 0.738685994709706

# %%
print(f'DT model calssification report : {classification_report(y_test_unscaled,dt_y_predict)}')
# Out:
# DT model calssification report :               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77       109
#            1       0.64      0.74      0.68        69
#
#     accuracy                           0.74       178
#    macro avg       0.73      0.74      0.73       178
# weighted avg       0.75      0.74      0.74       178

# %%
print(f'DT model accuray score : {accuracy_score(y_test_unscaled,dt_y_predict)}')
# Out:
# DT model accuray score : 0.7359550561797753

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='rbf')
svm_model.fit(X_test_scaled,y_test_scaled)
svm_y_predd = svm_model.predict(X_test_scaled)

# %%
print(f'SVM model f-1 score : {f1_score(y_test_scaled,svm_y_predd,average="weighted")}')
# Out:
# SVM model f-1 score : 0.8471638864380178

# %%
print(f'SVM model calssification report : {classification_report(y_test_scaled,svm_y_predd)}')
# Out:
# SVM model calssification report :               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88       109
#            1       0.83      0.77      0.80        69
#
#     accuracy                           0.85       178
#    macro avg       0.84      0.83      0.84       178
# weighted avg       0.85      0.85      0.85       178

# %%
print(f'SVM model accuray score : {accuracy_score(y_test_scaled,svm_y_predd)}')
# Out:
# SVM model accuray score : 0.848314606741573

# %% [markdown]
# ## tuning.....

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(knn_model,X_train_scaled,y_train_scaled,cv=5, scoring='accuracy')
score.mean()
# Out:
# 0.8101053875701762

# %%
score2 = cross_val_score(model_dt,X_train_scaled,y_train_scaled,cv=5, scoring='accuracy')
score2.mean()
# Out:
# 0.7975573722052596

# %%
score3 = cross_val_score(svm_model,X_train_scaled,y_train_scaled,cv=5, scoring='accuracy')
score3.mean()
# Out:
# 0.8283955481138581

# %%
score4 = cross_val_score(nb_model,X_train_scaled,y_train_scaled,cv=5, scoring='accuracy')
score4.mean()
# Out:
# 0.7833842214123904
